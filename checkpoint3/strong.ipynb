# %%
import torch
import numpy as np
import time

import hockey.hockey_env as h_env

from sac.plots import *
from sac.utils import from_dict, SB3_PARAMS
from sac.trainer import HockeyTrainer

# %%
params = SB3_PARAMS
hidden_sizes = [256, 256]
params["alpha"] = 0.01
params["hidden_sizes"] = hidden_sizes

# %%
random_seed = 0

# %%
if random_seed is not None:
    torch.manual_seed(random_seed)
    np.random.seed(random_seed)

# %%
filepath = f"./results/strong-{random_seed}"

# %%
trainer = HockeyTrainer(params)
opponent = h_env.BasicOpponent(weak=False)

# %%
# trainer.load(f"./results/test-{random_seed}-1596.pth")
# trainer.load(f"../checkpoint2/defense/results/SAC-Defense-0-3639.pth")

# %%
trainer.warmup(256)

# %%
max_timesteps = 500
new_episodes = 500
log_interval = 20
train_interval = 20

# %%
trainer.train(opponent, new_episodes, train_interval, log_interval, max_timesteps)
# Out:
#     20: Reward:  -25.986 Winrate:    0.450
#     40: Reward:  -25.058 Winrate:    0.325
#     60: Reward:  -21.070 Winrate:    0.300
#     80: Reward:  -23.310 Winrate:    0.300
#    100: Reward:  -19.318 Winrate:    0.325
#    120: Reward:  -22.014 Winrate:    0.375
#    140: Reward:  -16.311 Winrate:    0.350
#    160: Reward:  -15.322 Winrate:    0.250
#    180: Reward:  -22.002 Winrate:    0.375
#    200: Reward:  -16.894 Winrate:    0.250
#    220: Reward:  -19.262 Winrate:    0.325
#    240: Reward:  -16.066 Winrate:    0.500
#    260: Reward:  -15.608 Winrate:    0.275
#    280: Reward:  -23.530 Winrate:    0.325
#    300: Reward:  -21.222 Winrate:    0.250
#    320: Reward:  -18.620 Winrate:    0.375
#    340: Reward:  -19.308 Winrate:    0.400
#    360: Reward:  -18.001 Winrate:    0.275
#    380: Reward:  -20.473 Winrate:    0.275
#    400: Reward:  -17.163 Winrate:    0.300
#    420: Reward:  -13.197 Winrate:    0.275
#    440: Reward:  -10.516 Winrate:    0.425
#    460: Reward:  -11.875 Winrate:    0.350
#    480: Reward:  -11.117 Winrate:    0.375
#    500: Reward:  -12.966 Winrate:    0.375

# %%
rewards, scores = trainer.evaluate(opponent, 100, render=False)
np.mean(rewards), 0.5 * (np.mean(scores)+1)
# Out:
# (np.float64(-12.563912837726477), np.float64(0.345))

# %%
trainer.evaluate(opponent, render=True)
# Out:
# ([-13.913249200105675,
#   9.432609681150831,
#   -15.605464172963817,
#   -24.23383590909188,
#   -16.222194259779023],
#  [-1, 1, -1, 0, -1])

# %%
trainer.reset()

# %%
trainer.save_agent(filepath)

# %%
for i in range(9):
    trainer.train(opponent, new_episodes, train_interval, log_interval, max_timesteps)
    rewards, scores = trainer.evaluate(opponent, 100, render=False)
    print("Avg reward:",np.mean(rewards))
    print("Winrate:",0.5 * (np.mean(scores)+1))
    trainer.save_agent(filepath)
# Out:
#    520: Reward:  -14.459 Winrate:    0.350
#    540: Reward:   -8.419 Winrate:    0.375
#    560: Reward:   -8.190 Winrate:    0.475
#    580: Reward:  -15.110 Winrate:    0.325
#    600: Reward:  -12.529 Winrate:    0.400
#    620: Reward:  -13.104 Winrate:    0.350
#    640: Reward:  -17.150 Winrate:    0.250
#    660: Reward:  -10.570 Winrate:    0.350
#    680: Reward:  -17.762 Winrate:    0.275
#    700: Reward:   -7.261 Winrate:    0.400
#    720: Reward:  -14.145 Winrate:    0.375
#    740: Reward:  -16.604 Winrate:    0.350
#    760: Reward:  -11.211 Winrate:    0.475
#    780: Reward:  -11.779 Winrate:    0.350
#    800: Reward:   -6.853 Winrate:    0.450
#    820: Reward:   -8.897 Winrate:    0.350
#    840: Reward:   -4.314 Winrate:    0.450
#    860: Reward:   -4.822 Winrate:    0.375
#    880: Reward:   -9.156 Winrate:    0.275
#    900: Reward:   -6.953 Winrate:    0.350
#    920: Reward:   -6.429 Winrate:    0.375
#    940: Reward:   -5.984 Winrate:    0.375
#    960: Reward:   -5.566 Winrate:    0.400
#    980: Reward:   -6.152 Winrate:    0.400
#   1000: Reward:   -7.199 Winrate:    0.400
# Avg reward: -8.72931095968308
# Winrate: 0.265
#   1020: Reward:   -6.161 Winrate:    0.375
#   1040: Reward:   -6.055 Winrate:    0.400
#   1060: Reward:   -5.455 Winrate:    0.400
#   1080: Reward:   -6.474 Winrate:    0.400
#   1100: Reward:   -9.691 Winrate:    0.300
#   1120: Reward:   -2.286 Winrate:    0.550
#   1140: Reward:   -8.693 Winrate:    0.325
#   1160: Reward:   -5.267 Winrate:    0.450
#   1180: Reward:   -5.902 Winrate:    0.475
#   1200: Reward:   -3.382 Winrate:    0.525
#   1220: Reward:   -8.590 Winrate:    0.300
#   1240: Reward:   -3.897 Winrate:    0.500
#   1260: Reward:   -9.149 Winrate:    0.325
#   1280: Reward:   -5.901 Winrate:    0.425
#   1300: Reward:   -6.598 Winrate:    0.450
#   1320: Reward:   -7.199 Winrate:    0.400
#   1340: Reward:   -7.335 Winrate:    0.350
#   1360: Reward:   -5.704 Winrate:    0.475
#   1380: Reward:   -4.751 Winrate:    0.525
#   1400: Reward:   -4.936 Winrate:    0.450
#   1420: Reward:   -8.292 Winrate:    0.475
#   1440: Reward:   -7.262 Winrate:    0.350
#   1460: Reward:   -5.266 Winrate:    0.450
#   1480: Reward:   -6.780 Winrate:    0.400
#   1500: Reward:   -4.324 Winrate:    0.600
# Avg reward: -5.347700206493597
# Winrate: 0.46499999999999997
#   1520: Reward:   -5.458 Winrate:    0.450
#   1540: Reward:   -9.025 Winrate:    0.475
#   1560: Reward:   -5.271 Winrate:    0.525
#   1580: Reward:   -0.897 Winrate:    0.675
#   1600: Reward:   -6.998 Winrate:    0.400
#   1620: Reward:   -6.157 Winrate:    0.525
#   1640: Reward:   -4.430 Winrate:    0.550
#   1660: Reward:   -5.952 Winrate:    0.450
#   1680: Reward:   -6.842 Winrate:    0.425
#   1700: Reward:   -6.611 Winrate:    0.500
#   1720: Reward:   -4.405 Winrate:    0.550
#   1740: Reward:   -4.876 Winrate:    0.500
#   1760: Reward:   -4.954 Winrate:    0.525
#   1780: Reward:   -7.773 Winrate:    0.325
#   1800: Reward:   -6.530 Winrate:    0.475
#   1820: Reward:   -5.789 Winrate:    0.500
#   1840: Reward:   -4.239 Winrate:    0.525
#   1860: Reward:   -5.262 Winrate:    0.550
#   1880: Reward:   -6.614 Winrate:    0.425
#   1900: Reward:   -1.617 Winrate:    0.625
#   1920: Reward:   -3.178 Winrate:    0.550
#   1940: Reward:   -3.763 Winrate:    0.550
#   1960: Reward:   -3.935 Winrate:    0.525
#   1980: Reward:   -6.256 Winrate:    0.425
#   2000: Reward:   -4.499 Winrate:    0.525
# Avg reward: -3.9469732196248906
# Winrate: 0.54
#   2020: Reward:   -6.568 Winrate:    0.450
#   2040: Reward:   -3.896 Winrate:    0.500
#   2060: Reward:   -5.440 Winrate:    0.450
#   2080: Reward:   -1.658 Winrate:    0.700
#   2100: Reward:   -5.127 Winrate:    0.500
#   2120: Reward:   -2.669 Winrate:    0.675
#   2140: Reward:   -0.477 Winrate:    0.675
#   2160: Reward:   -3.551 Winrate:    0.650
#   2180: Reward:   -5.512 Winrate:    0.575
#   2200: Reward:   -4.833 Winrate:    0.550
#   2220: Reward:   -1.595 Winrate:    0.650
#   2240: Reward:   -7.538 Winrate:    0.450
#   2260: Reward:   -3.962 Winrate:    0.550
#   2280: Reward:   -4.521 Winrate:    0.525
#   2300: Reward:   -2.249 Winrate:    0.650
#   2320: Reward:   -3.982 Winrate:    0.625
#   2340: Reward:   -3.617 Winrate:    0.575
#   2360: Reward:   -3.020 Winrate:    0.550
#   2380: Reward:   -5.320 Winrate:    0.475
#   2400: Reward:   -0.438 Winrate:    0.650
#   2420: Reward:   -8.183 Winrate:    0.425
#   2440: Reward:   -6.248 Winrate:    0.475
#   2460: Reward:   -5.880 Winrate:    0.475
#   2480: Reward:   -0.593 Winrate:    0.700
#   2500: Reward:   -3.460 Winrate:    0.550
# Avg reward: -1.0830649397897412
# Winrate: 0.675
#   2520: Reward:   -1.700 Winrate:    0.625
#   2540: Reward:   -3.607 Winrate:    0.575
#   2560: Reward:   -0.823 Winrate:    0.625
#   2580: Reward:   -2.269 Winrate:    0.625
#   2600: Reward:   -5.260 Winrate:    0.475
#   2620: Reward:   -1.711 Winrate:    0.625
#   2640: Reward:   -4.148 Winrate:    0.500
#   2660: Reward:   -4.145 Winrate:    0.550
#   2680: Reward:   -3.989 Winrate:    0.500
#   2700: Reward:   -2.910 Winrate:    0.600
#   2720: Reward:   -4.688 Winrate:    0.525
#   2740: Reward:   -1.772 Winrate:    0.600
#   2760: Reward:    1.019 Winrate:    0.750
#   2780: Reward:   -2.902 Winrate:    0.600
#   2800: Reward:   -1.315 Winrate:    0.625
#   2820: Reward:   -5.237 Winrate:    0.500
#   2840: Reward:   -3.123 Winrate:    0.575
#   2860: Reward:   -2.879 Winrate:    0.600
#   2880: Reward:   -2.998 Winrate:    0.600
#   2900: Reward:   -2.105 Winrate:    0.600
#   2920: Reward:   -5.359 Winrate:    0.475
#   2940: Reward:   -2.606 Winrate:    0.625
#   2960: Reward:   -5.935 Winrate:    0.475
#   2980: Reward:   -4.416 Winrate:    0.550
#   3000: Reward:   -1.184 Winrate:    0.625
# Avg reward: -2.115942344312268
# Winrate: 0.58
#   3020: Reward:   -0.366 Winrate:    0.650
#   3040: Reward:   -1.830 Winrate:    0.625
#   3060: Reward:   -3.018 Winrate:    0.600
#   3080: Reward:   -4.465 Winrate:    0.525
#   3100: Reward:   -1.888 Winrate:    0.675
#   3120: Reward:   -1.038 Winrate:    0.650
#   3140: Reward:   -2.566 Winrate:    0.600
#   3160: Reward:   -1.223 Winrate:    0.625
#   3180: Reward:    0.599 Winrate:    0.750
#   3200: Reward:    1.498 Winrate:    0.750
#   3220: Reward:   -2.813 Winrate:    0.575
#   3240: Reward:   -0.725 Winrate:    0.675
#   3260: Reward:   -1.564 Winrate:    0.650
#   3280: Reward:   -4.143 Winrate:    0.525
#   3300: Reward:   -0.858 Winrate:    0.625
#   3320: Reward:   -1.889 Winrate:    0.625
#   3340: Reward:   -0.838 Winrate:    0.675
#   3360: Reward:    1.567 Winrate:    0.775
#   3380: Reward:   -3.821 Winrate:    0.525
#   3400: Reward:   -0.146 Winrate:    0.675
#   3420: Reward:   -1.307 Winrate:    0.625
#   3440: Reward:   -1.496 Winrate:    0.625
#   3460: Reward:   -2.816 Winrate:    0.575
#   3480: Reward:   -1.517 Winrate:    0.650
#   3500: Reward:   -0.203 Winrate:    0.675
# Avg reward: -0.7646649958130805
# Winrate: 0.685
#   3520: Reward:   -3.964 Winrate:    0.550
#   3540: Reward:   -3.319 Winrate:    0.575
#   3560: Reward:   -0.216 Winrate:    0.700
#   3580: Reward:   -1.465 Winrate:    0.650
#   3600: Reward:   -5.974 Winrate:    0.500
#   3620: Reward:   -2.921 Winrate:    0.575
#   3640: Reward:    0.161 Winrate:    0.675
#   3660: Reward:   -0.180 Winrate:    0.725
#   3680: Reward:    0.769 Winrate:    0.725
#   3700: Reward:   -3.008 Winrate:    0.600
#   3720: Reward:   -1.287 Winrate:    0.675
#   3740: Reward:    1.248 Winrate:    0.750
#   3760: Reward:    1.498 Winrate:    0.800
#   3780: Reward:   -2.869 Winrate:    0.600
#   3800: Reward:   -5.170 Winrate:    0.450
#   3820: Reward:   -1.057 Winrate:    0.600
#   3840: Reward:    0.946 Winrate:    0.700
#   3860: Reward:    0.776 Winrate:    0.725
#   3880: Reward:   -3.801 Winrate:    0.525
#   3900: Reward:   -2.217 Winrate:    0.650
#   3920: Reward:    0.610 Winrate:    0.750
#   3940: Reward:   -0.241 Winrate:    0.700
#   3960: Reward:   -3.549 Winrate:    0.600
#   3980: Reward:    0.690 Winrate:    0.725
#   4000: Reward:    1.459 Winrate:    0.700
# Avg reward: 0.714998468833602
# Winrate: 0.6950000000000001
#   4020: Reward:   -4.752 Winrate:    0.475
#   4040: Reward:   -1.465 Winrate:    0.675
#   4060: Reward:    0.867 Winrate:    0.750
#   4080: Reward:   -2.842 Winrate:    0.575
#   4100: Reward:   -1.051 Winrate:    0.625
#   4120: Reward:   -3.235 Winrate:    0.550
#   4140: Reward:   -3.369 Winrate:    0.525
#   4160: Reward:   -2.111 Winrate:    0.575
#   4180: Reward:    0.122 Winrate:    0.725
#   4200: Reward:   -2.819 Winrate:    0.575
#   4220: Reward:    1.146 Winrate:    0.775
#   4240: Reward:   -3.554 Winrate:    0.575
#   4260: Reward:   -2.050 Winrate:    0.600
#   4280: Reward:   -1.560 Winrate:    0.600
#   4300: Reward:   -2.790 Winrate:    0.600
#   4320: Reward:   -1.055 Winrate:    0.650
#   4340: Reward:   -2.755 Winrate:    0.550
#   4360: Reward:   -0.625 Winrate:    0.650
#   4380: Reward:   -2.524 Winrate:    0.600
#   4400: Reward:    0.261 Winrate:    0.725
#   4420: Reward:   -1.982 Winrate:    0.575
#   4440: Reward:    1.739 Winrate:    0.775
#   4460: Reward:    1.580 Winrate:    0.725
#   4480: Reward:   -0.021 Winrate:    0.700
#   4500: Reward:   -1.309 Winrate:    0.600
# Avg reward: -1.6607660208811674
# Winrate: 0.59
#   4520: Reward:   -0.731 Winrate:    0.625
#   4540: Reward:   -1.628 Winrate:    0.625
#   4560: Reward:   -1.040 Winrate:    0.625
#   4580: Reward:    1.562 Winrate:    0.750
#   4600: Reward:   -2.046 Winrate:    0.575
#   4620: Reward:    0.191 Winrate:    0.725
#   4640: Reward:    0.521 Winrate:    0.725
#   4660: Reward:    0.031 Winrate:    0.675
#   4680: Reward:   -1.327 Winrate:    0.625
#   4700: Reward:   -2.714 Winrate:    0.575
#   4720: Reward:    0.647 Winrate:    0.700
#   4740: Reward:    1.598 Winrate:    0.725
#   4760: Reward:   -5.422 Winrate:    0.475
#   4780: Reward:    0.680 Winrate:    0.650
#   4800: Reward:   -0.439 Winrate:    0.650
#   4820: Reward:    1.614 Winrate:    0.750
#   4840: Reward:   -0.962 Winrate:    0.625
#   4860: Reward:    0.595 Winrate:    0.675
#   4880: Reward:   -1.919 Winrate:    0.625
#   4900: Reward:   -2.193 Winrate:    0.625
#   4920: Reward:   -0.950 Winrate:    0.650
#   4940: Reward:   -1.927 Winrate:    0.575
#   4960: Reward:    1.100 Winrate:    0.700
#   4980: Reward:   -3.586 Winrate:    0.525
#   5000: Reward:   -1.652 Winrate:    0.625
# Avg reward: -0.9349254438697823
# Winrate: 0.64

# %%
q_losses = np.stack([trainer.logs["Q1_loss"], trainer.logs["Q2_loss"]]).T
plot_q(q_losses, "./results")

# %%
plot_policy_loss(trainer.logs["Policy_loss"], "./results")

# %%
plot_entropy(np.asarray(trainer.logs["Logprobs"]), "./results")

# %%
plot_rewards(trainer.logs["Rewards"], "./results")

# %%
plt.plot(running_mean(0.5*(np.asarray(trainer.logs["Scores"])+1), 50))

# %%
plt.plot(running_mean(trainer.logs["Lengths"], 50))

# %%
trainer.evaluate(opponent, 10, render=True)
# Out:
# ([9.58605120584371,
#   9.55736888111625,
#   -11.431473124672667,
#   9.539714189271045,
#   -3.44601041668548,
#   9.724531691396177,
#   6.138460734562132,
#   -11.664755510801442,
#   -7.407107651639524,
#   -12.117607727895628],
#  [1, 1, -1, 1, 0, 1, 1, -1, 0, -1])

# %%
trainer.reset()

# %%
rewards, scores = trainer.evaluate(opponent, 1000, render=False)
np.mean(rewards), 0.5 * (np.mean(scores)+1)
# Out:
# (np.float64(-0.3387637884433925), np.float64(0.6765))

# %%
rewards, scores = trainer.evaluate(h_env.BasicOpponent(), 1000, render=False)
np.mean(rewards), 0.5 * (np.mean(scores)+1)
# Out:
# (np.float64(-1.9451479265371412), np.float64(0.5555))
